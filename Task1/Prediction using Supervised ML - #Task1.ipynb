# %%
# Importing libraries required in this notebook
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
# Reading data from web link
tdf = pd.read_csv("https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv")
print("Data imported successfully")

tdf.head()
# Out:
# Data imported successfully
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Hours</th>
#       <th>Scores</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2.5</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5.1</td>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3.2</td>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>8.5</td>
#       <td>75</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.5</td>
#       <td>30</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# To get description of data
tdf.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Hours</th>
#       <th>Scores</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>25.000000</td>
#       <td>25.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>5.012000</td>
#       <td>51.480000</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>2.525094</td>
#       <td>25.286887</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>1.100000</td>
#       <td>17.000000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>2.700000</td>
#       <td>30.000000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>4.800000</td>
# ...

# %%
tdf.shape
# Out:
# Out[4]: (25, 2)

# %%
#Distribution of scores
tdf.plot(kind='scatter',x='Hours',y='Scores',figsize=(10,10))
plt.title("Hours VS Percentage")
plt.xlabel("Hours")
plt.ylabel("Percentage")
# Out:
# Out[5]: Text(0, 0.5, 'Percentage')

# %%
#Preparing data
X = tdf.iloc[:, :-1].values  
y = tdf.iloc[:, 1].values

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#Train algorithm
from sklearn.linear_model import LinearRegression  
regressor = LinearRegression()  
regressor.fit(X_train, y_train) 

print("Training Complete")
# Out:
# Training Complete

# %%
# Plotting the regression line
line = regressor.coef_*X+regressor.intercept_

# Plotting for the test data
plt.scatter(X, y)
plt.plot(X, line);
plt.show()

# %%
#Making Predictions
print(X_test) # Testing data - In Hours
# Predicting the scores
y_pred = regressor.predict(X_test)
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]

# %%
# Comparing Actual vs Predicted
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})  
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Actual</th>
#       <th>Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>20</td>
#       <td>16.884145</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>27</td>
#       <td>33.732261</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>69</td>
#       <td>75.357018</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>30</td>
#       <td>26.794801</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>62</td>
#       <td>60.491033</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Solving the given problem
hours = [[9.25]]
mytest = regressor.predict(hours)
print("No of Hours = {}".format(hours))
print("Predicted Score = {}".format(mytest[0]))
# Out:
# No of Hours = [[9.25]]
# Predicted Score = 93.69173248737539

# %%
#Evaluating the model
from sklearn import metrics  
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.183859899002982
